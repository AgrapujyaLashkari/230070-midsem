# %% [markdown]
# ## Task 2.3: Result and Discussion
# * **Reported Result**: The reproduced model achieved an accuracy of ~90-95% on the toy dataset. The paper reported ~76.38% (100% - 23.62% 0/1 Loss) for ORTHOGNL on the CCAT dataset (Table 2).
# * **Discussion**: The performance gap (higher accuracy on my toy dataset) is entirely expected because my synthetic dataset is low-dimensional (13 features) and specifically designed to be highly informative, unlike the massive, noisy, sparse TF-IDF text arrays (47,236 features) evaluated in the original paper.
#
# ## Reproducibility Checklist
# * [x] Random seeds are set and documented at the top of each notebook, where applicable.
# * [x] All dependencies are listed in `requirements.txt` with version numbers.
# * [x] All notebooks run from top to bottom in a clean environment without errors. Dataset loading requires no undocumented manual steps.
# * [x] All hyperparameters are clearly named and defined in one place rather than scattered across cells.
