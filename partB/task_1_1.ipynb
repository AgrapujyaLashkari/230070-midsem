# %% [markdown]
# ## Task 1.1: Core Contribution / Architecture
#
# **Step 1: Recursive Classification Initialization**
# * **Description**: The classification process begins at the root node (denoted as $0$) of the category tree.
# * **Reference**: Section 2, Equation (1).
# * **Purpose**: To establish the starting point for traversing the hierarchy.
#
# **Step 2: Sibling Evaluation**
# * **Description**: The algorithm calculates the inner product $w_j^T x$ for all immediate children of the current node to evaluate the classification score.
# * **Reference**: Section 2, Equation (1).
# * **Purpose**: To score how well the input feature vector matches each of the immediate sub-categories.
#
# **Step 3: Traversal and Selection**
# * **Description**: The algorithm selects the child node with the highest score, updates the current node to this winner, and repeats Step 2 until a leaf node is reached.
# * **Reference**: Section 2, Equation (1).
# * **Purpose**: To recursively navigate down the hierarchy and output a final specific class label.
#
# **Final Summary Sentence:**
# This paper solves the problem of misclassifications between highly similar classes at lower levels of a category tree by claiming that enforcing orthogonality between a node's classification hyperplane and its ancestors' hyperplanes prevents the model from relying on the same generic features, leading to better specialization.
